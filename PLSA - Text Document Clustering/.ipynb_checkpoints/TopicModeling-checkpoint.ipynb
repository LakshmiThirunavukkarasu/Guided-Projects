# %% [markdown]
# # Load the libraries

# %%
#https://towardsdatascience.com/topic-modeling-quora-questions-with-lda-nmf-aff8dce5e1dd

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import re

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfTransformer, TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer, CountVectorizer
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.preprocessing import Normalizer

# %%
import nltk
import ssl

try:
    _create_unverified_https_context = ssl._create_unverified_context
except AttributeError:
    ssl._create_default_https_context = _create_unverified_https_context
    
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %% [markdown]
# # Load the dataset

# %%
categories = [
    'alt.atheism',
    'talk.religion.misc',
    'comp.graphics',
    'sci.space'
]

data_train = fetch_20newsgroups(subset='train', 
                                remove=('headers', 'footers', 'quotes'),
                                categories=categories, 
                                shuffle=True, random_state=42)

df_train = pd.DataFrame(data_train.data)
labels_train = data_train.target

data_test = fetch_20newsgroups(subset='test', 
                               remove=('headers', 'footers', 'quotes'),
                               categories=categories, 
                               shuffle=True, random_state=42)

df_test = pd.DataFrame(data_test.data)
f = data_test.target

# %%
data_train.target_names
# Out:
# ['alt.atheism', 'comp.graphics', 'sci.space', 'talk.religion.misc']

# %%
print(pd.DataFrame(labels_train).value_counts())
print("----------")
print(pd.DataFrame(labels_test).value_counts())
# Out:
# 2    593
# 1    584
# 0    480
# 3    377
# dtype: int64
# ----------
# 2    394
# 1    389
# 0    319
# 3    251
# dtype: int64

# %% [markdown]
# # Load the stopwords

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')

stopw = stopwords.words('english')
file1 = open('stopwords.txt','r')

# Use this to read file content as a stream:
line = file1.read()
customstopwords = line.split()
stopw.extend(customstopwords)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\venka\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Preprocessing functions

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import wordnet as wn
from nltk import pos_tag

def steming(x):
    from nltk.stem import PorterStemmer
    
    #ps = PorterStemmer()
    stemmer = nltk.stem.SnowballStemmer('english')
    
    words = word_tokenize(x)
    
    refined_sent = [stemmer.stem(w) for w in words ]
    #print(refined_sent)
    return ' '.join(refined_sent) 

def lemmatizer(x):
    from collections import defaultdict
    from nltk.stem.wordnet import WordNetLemmatizer
    
    tag_map = defaultdict(lambda : wn.NOUN)
    tag_map['J'] = wn.ADJ
    tag_map['V'] = wn.VERB
    tag_map['R'] = wn.ADV
    
    #tag_list = ['NN', 'NNS','NNP','NNPS','VB','VBG','VBN','VBP','VBZ']
    tag_list = ['IN','VBN','RB','RBR','RBS','JJR','DT','UH','WDT','WP','WP$','WRB','VBG','MD','PRP','PRP$','CC']
    
    
    #words = word_tokenize(x)
    words = x.split(' ')
    lemma_function = WordNetLemmatizer()
    #refined_sent = [lemma_function.lemmatize(token, tag_map[tag[0]]) for token, tag in pos_tag(words)]
    #refined_sent = [lemma_function.lemmatize(token) for token, tag in pos_tag(words) if tag not in tag_list ]
    refined_sent = list()
    for token, tag in pos_tag(words):
        if  len(token) > 3 :
            if tag not in tag_list:
                tag_l = tag.lower()
                if tag.lower() in ['a', 'r', 'n', 'v']:
                    refined_sent.append(lemma_function.lemmatize(token,tag_l))
                else:
                    refined_sent.append(lemma_function.lemmatize(token))
                             
    return ' '.join(refined_sent) 


def remove_sentence(x):
    x = x.split("\n")
    refined_sent = [sent for sent in x if not (sent.strip().startswith("from") \
                                       or sent.strip().startswith("subject") \
                                       or sent.strip().startswith('nntp') \
                                       or sent.strip().startswith('organization'))] 
    
    return ' '.join(refined_sent)

def stop_words(x):
    x = x.replace('\r\n','')
    terms = x.split(' ')
    refined_sent = [w.strip() for w in terms if (w.strip() not in stopw)  and (len(w.strip()) > 2)]
    #print(refined_sent)
    return  ' '.join(refined_sent)

# %%
df_train[0] = df_train[0].map(lambda x: x.lower())
df_train[0] = df_train[0].apply(lambda x: remove_sentence(x))
df_train[0] = df_train[0].apply(lambda x: stop_words(x)) 
df_train[0] = df_train[0].map(lambda x: re.sub(r'[\w\.-]+@[\w\.-]+','',x))
df_train[0] = df_train[0].map(lambda x: re.sub('[,\.!?_=()"|><*]', '', x))
df_train[0] = df_train[0].map(lambda x: re.sub(r'[0-9]+', '', x))
df_train[0] = df_train[0].apply(lambda x: lemmatizer(x))
#df_train[0] = df_train[0].apply(lambda x: steming(x))
#df_train[0] = df_train[0].apply(lambda x: stop_words(x)) 

pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\venka\AppData\Local\Temp\ipykernel_14408\971898935.py:11: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %%
#n_components = 5
#labels = data_train.target
#true_k = np.unique(labels).shape[0]


df_test[0] = df_test[0].map(lambda x: x.lower())
df_test[0] = df_test[0].apply(lambda x: remove_sentence(x))
df_test[0] = df_test[0].map(lambda x: re.sub(r'[\w\.-]+@[\w\.-]+','',x))
df_test[0] = df_test[0].map(lambda x: re.sub('[,\.!?_=()"|><*]', '', x))
df_test[0] = df_test[0].map(lambda x: re.sub(r'[0-9]+', '', x))
df_test[0] = df_test[0].apply(lambda x: Lemmatizer(x)) 
#df_test[0] = df_test[0].apply(lambda x: steming(x)) 
df_test[0] = df_test[0].apply(lambda x: stop_words(x)) 
pd.set_option('display.max_colwidth', -1)
# Out:
# C:\Users\venka\AppData\Local\Temp\ipykernel_14408\1681283281.py:14: FutureWarning: Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.
#   pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# # TFIDF Vectorizer

# %% [markdown]
# max_df is used for removing terms that appear too frequently, also known as "corpus-specific stop words"
#
# max_df = 0.50 means "ignore terms that appear in more than 50% of the documents".
# max_df = 25 means "ignore terms that appear in more than 25 documents".
#
# min_df is used for removing terms that appear too infrequently. For example:
#
# min_df = 0.01 means "ignore terms that appear in less than 1% of the documents".
# min_df = 5 means "ignore terms that appear in less than 5 documents".

# %%
# Convert to TF-IDF format
vectorizer_train = TfidfVectorizer(max_df=0.50, min_df=0.01, stop_words=None,use_idf=True, max_features = 1000,lowercase=False, ngram_range=(1,2))

#,,lowercase=False, ngram_range(1,2))
X_train = vectorizer_train.fit_transform(df_train[0])
print(X_train.shape)
print(vectorizer_train.get_feature_names_out())

print("------------------")

#vectorizer_test = TfidfVectorizer(max_df=0.50, min_df=0.07, stop_words='english', use_idf=True)
X_test = vectorizer_train.transform(df_test[0])
print(X_test.shape)
print(vectorizer.get_feature_names_out())

# Reduce dimensions
#svd = TruncatedSVD(n_components)
#normalizer = Normalizer(copy=False)
# lsa = make_pipeline(svd, normalizer)

# X_train = lsa.fit_transform(X_train)

#first_vector_tfidfvectorizer=X_train[1]
#x  = pd.DataFrame(first_vector_tfidfvectorizer.T.todense(),index=vectorizer.get_feature_names(),columns=["tfidf"])
#x.sort_values(by=["tfidf"],ascending=False)
# Out:
# (2034, 1000)
# ['ability' 'able' 'absolute' 'accept' 'acceptable' 'accepted' 'access'
#  'account' 'accurate' 'act' 'action' 'activity' 'actual' 'adam' 'added'
#  'addition' 'additional' 'address' 'admit' 'advance' 'advanced'
#  'advantage' 'agency' 'agree' 'algorithm' 'alive' 'allen' 'allow' 'allows'
#  'alternative' 'america' 'american' 'ames' 'amount' 'analysis' 'and'
#  'and or' 'animal' 'animation' 'anonymous' 'answer' 'answer question'
#  'anti' 'anyone' 'anything' 'apollo' 'appear' 'appears' 'application'
#  'apply' 'appreciate' 'appreciated' 'approach' 'appropriate' 'april'
#  'archive' 'archive name' 'are' 'area' 'argue' 'argument' 'article'
#  'asked' 'aspect' 'assume' 'assumption' 'astronomy' 'atheism' 'atheist'
#  'attack' 'attempt' 'attitude' 'author' 'authority' 'available' 'avoid'
#  'aware' 'away' 'back' 'background' 'ball' 'bank' 'base' 'based' 'basic'
#  'basis' 'became' 'become' 'becomes' 'begin' 'behavior' 'being' 'belief'
# ...

# %%
X_train.A

# %%
pd.DataFrame(data_train.target).value_counts()

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
lda = LDA(n_components=3, solver='eigen',shrinkage= 'auto')
clf = lda.fit(X_train.toarray(), labels_train)
clf_l = clf.transform(X_train.toarray())
print(clf_l)
# Out:
# [[-0.37876097 -1.28821821 -3.31401192]
#  [-1.68931394  0.7238032   0.72412361]
#  [-0.78170468  0.82055733 -1.03044158]
#  ...
#  [ 0.54161868 -1.02948929 -2.03311111]
#  [-5.08890495  1.00446825 -1.96939256]
#  [ 0.          0.          0.        ]]

# %%
clf_pred = clf.predict(X_train.toarray())
train_score = accuracy_score(labels_train, clf_pred) * 100
print(f"Train accuracy score: {train_score:.2f}%")

clf_pred = clf.predict(X_test.toarray())
test_score = accuracy_score(labels_test, clf_pred) * 100
print(f"Test accuracy score: {test_score:.2f}%")
# Out:
# Train accuracy score: 79.50%
# Test accuracy score: 63.41%

# %%
# Percentage of variance explained for each components
print(
    "explained variance ratio (first two components): %s"
    % str(lda.explained_variance_ratio_)
)
# Out:
# explained variance ratio (first two components): [0.00791694 0.0079167  0.00791315]

# %%
plt.figure()
colors = ["navy", "turquoise", "darkorange","green"]
lw = 2

target_names = data_train.target_names

for color, i, target_names in zip(colors, [0, 1, 2,3], target_names):
    plt.scatter(
        clf_l[labels_train == i, 0], clf_l[labels_train == i, 1], color=color, alpha=0.8, lw=lw, label=target_names
    )
plt.legend(loc="best", shadow=False, scatterpoints=1)
plt.title("LDA of News Group dataset")
# Out:
# Text(0.5, 1.0, 'LDA of News Group dataset')

# %%
lr_pred = clf.predict(X_test.toarray())
cm = confusion_matrix(labels_test, lr_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=data_train.target_names)


# NOTE: Fill all variables here with default values of the plot_confusion_matrix
fig, ax = plt.subplots(figsize=(10, 10))
disp = disp.plot(xticks_rotation='vertical', ax=ax, cmap='summer')

plt.show()

# %%
#PLSA

# %%
#Number of topcis
from sklearn.decomposition import NMF
no_of_topics = 4
model = NMF(n_components = no_of_topics, init='nndsvd',regularization='components', random_state = 111 )
W1 = model.fit_transform(X_train)
H1 = model.components_
# Out:
# C:\Users\venka\miniconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1432: FutureWarning: `regularization` was deprecated in version 1.0 and will be removed in 1.2. Use `alpha_W` and `alpha_H` instead
#   warnings.warn(

# %%
print(sa)
# Out:
# [[0.         0.2604488  0.         0.00038453]
#  [0.04146547 0.         0.         0.03107275]
#  [0.04775392 0.         0.         0.        ]
#  ...
#  [0.01904116 0.04216402 0.01084204 0.        ]
#  [0.10666598 0.         0.         0.01675986]
#  [0.         0.         0.         0.        ]]

# %%
def plot_top_words(model, feature_names, n_top_words, title):
    fig, axes = plt.subplots(1, 4, figsize=(30, 15), sharex=True)
    axes = axes.flatten()
    for topic_idx, topic in enumerate(model.components_):
        top_features_ind = topic.argsort()[: -n_top_words - 1 : -1]
        top_features = [feature_names[i] for i in top_features_ind]
        weights = topic[top_features_ind]

        ax = axes[topic_idx]
        ax.barh(top_features, weights, height=0.7)
        ax.set_title(f"Topic {topic_idx +1}", fontdict={"fontsize": 30})
        ax.invert_yaxis()
        ax.tick_params(axis="both", which="major", labelsize=20)
        for i in "top right left".split():
            ax.spines[i].set_visible(False)
        fig.suptitle(title, fontsize=40)

    plt.subplots_adjust(top=0.90, bottom=0.05, wspace=0.90, hspace=0.3)
    plt.show()

# %%
tfidf_feature_names = vectorizer_train.get_feature_names_out()
n_top_words = 20
plot_top_words(
    model, tfidf_feature_names, n_top_words, "Topics in NMF model (Frobenius norm)"
)

# %%
clf_pred = model.transform(X_train.toarray())
test_score = accuracy_score(labels_train, clf_pred) * 100
print(f"Train accuracy score: {train_score:.2f}%")

clf_pred = model.transform(X_test.toarray())
test_score = accuracy_score(labels_test, clf_pred) * 100
print(f"Test accuracy score: {test_score:.2f}%")
# Out:
# C:\Users\venka\miniconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1432: FutureWarning: `regularization` was deprecated in version 1.0 and will be removed in 1.2. Use `alpha_W` and `alpha_H` instead
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [116], in <cell line: 2>()
#       1 clf_pred = model.transform(X_train.toarray())
# ----> 2 test_score = accuracy_score(labels_train, clf_pred) * 100
#       3 print(f"Train accuracy score: {train_score:.2f}%")
#       5 clf_pred = model.transform(X_test.toarray())
#
# File ~\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:211, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     145 """Accuracy classification score.
#     146
#     147 In multilabel classification, this function computes subset accuracy:
#    (...)
#     207 0.5
#     208 """
# ...

# %%
clf_pred
# Out:
# array([[0.        , 0.        , 0.        , 0.191642  ],
#        [0.23853203, 0.        , 0.        , 0.        ],
#        [0.        , 0.        , 0.        , 0.        ],
#        ...,
#        [0.00815273, 0.03371969, 0.        , 0.01691013],
#        [0.00699651, 0.03763154, 0.11521437, 0.07571856],
#        [0.        , 0.        , 0.        , 0.        ]])

# %%
# lr_pred = lr_clf.predict(X_test.toarray())
lr_pred = model.transform(X_train)
cm = confusion_matrix(labels_train, lr_pred)



# lr_pred = lr_clf.predict(X_test.toarray())
lr_pred = model.transform(X_train)
cm = confusion_matrix(labels_train, lr_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=data_train.target_names)


# NOTE: Fill all variables here with default values of the plot_confusion_matrix
fig, ax = plt.subplots(figsize=(10, 10))
disp = disp.plot(xticks_rotation='vertical', ax=ax, cmap='summer')

plt.show()
# Out:
# C:\Users\venka\miniconda3\lib\site-packages\sklearn\decomposition\_nmf.py:1432: FutureWarning: `regularization` was deprecated in version 1.0 and will be removed in 1.2. Use `alpha_W` and `alpha_H` instead
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [600], in <cell line: 3>()
#       1 # lr_pred = lr_clf.predict(X_test.toarray())
#       2 lr_pred = model.transform(X_train)
# ----> 3 cm = confusion_matrix(labels_train, lr_pred)
#       4 disp = ConfusionMatrixDisplay(confusion_matrix=cm,
#       5                               display_labels=data_train.target_names)
#       8 # NOTE: Fill all variables here with default values of the plot_confusion_matrix
#
# File ~\miniconda3\lib\site-packages\sklearn\metrics\_classification.py:307, in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     222 def confusion_matrix(
# ...

# %% [raw]
# CC | Coordinating conjunction |
# CD | Cardinal number |
# DT | Determiner |
# EX | Existential there |
# FW | Foreign word |
# IN | Preposition or subordinating conjunction |
# JJ | Adjective |
# JJR | Adjective, comparative |
# JJS | Adjective, superlative |
# LS | List item marker |
# MD | Modal |
# NN | Noun, singular or mass |
# NNS | Noun, plural |
# NNP | Proper noun, singular |
# NNPS | Proper noun, plural |
# PDT | Predeterminer |
# POS | Possessive ending |
# PRP | Personal pronoun |
# PRP$ | Possessive pronoun |
# RB | Adverb |
# RBR | Adverb, comparative |
# RBS | Adverb, superlative |
# RP | Particle |
# SYM | Symbol |
# TO | to |
# UH | Interjection |
# VB | Verb, base form |
# VBD | Verb, past tense |
# VBG | Verb, gerund or present participle |
# VBN | Verb, past participle |
# VBP | Verb, non-3rd person singular present |
# VBZ | Verb, 3rd person singular present |
# WDT | Wh-determiner |
# WP | Wh-pronoun |
# WP$ | Possessive wh-pronoun |
# WRB | Wh-adverb |

# %%
from nltk.stem.wordnet import WordNetLemmatizer
#from collections import defaultdict
#print(pos_tag(['like']))

#NN, NNS , NNP, NNPS, VB , VBD, VBG, VBN,VBP,VBZ

#words = ['better']

#for token in words:
print(pos_tag(words))
#print("==============")

#lemma_function = WordNetLemmatizer()  
#refined_sent = [lemma_function.lemmatize(token) for token, tag in pos_tag(words) if tag not in tag_list]
#print(refined_sent)

lemma_function.lemmatize(['going'])
# Out:
# [('better', 'RBR')]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [345], in <cell line: 17>()
#      10 print(pos_tag(words))
#      11 #print("==============")
#      12
#      13 #lemma_function = WordNetLemmatizer()
#      14 #refined_sent = [lemma_function.lemmatize(token) for token, tag in pos_tag(words) if tag not in tag_list]
#      15 #print(refined_sent)
# ---> 17 lemma_function.lemmatize(['going'])
#
# File ~\miniconda3\lib\site-packages\nltk\stem\wordnet.py:45, in WordNetLemmatizer.lemmatize(self, word, pos)
#      33 def lemmatize(self, word: str, pos: str = "n") -> str:
#      34     """Lemmatize `word` using WordNet's built-in morphy function.
#      35     Returns the input word unchanged if it cannot be found in WordNet.
#      36
#    (...)
#      43     :return: The lemma of `word`, for the given `pos`.
#      44     """
# ...

# %%
pd.DataFrame(classification_report(y_test, lr_pred, output_dict=True)).T
# Out:
#               precision    recall  f1-score      support
# 0              0.851974  0.811912  0.831461   319.000000
# 1              0.883721  0.976864  0.927961   389.000000
# 2              0.927681  0.944162  0.935849   394.000000
# 3              0.830275  0.721116  0.771855   251.000000
# accuracy       0.881005  0.881005  0.881005     0.881005
# macro avg      0.873413  0.863513  0.866781  1353.000000
# weighted avg   0.879122  0.881005  0.878546  1353.000000
